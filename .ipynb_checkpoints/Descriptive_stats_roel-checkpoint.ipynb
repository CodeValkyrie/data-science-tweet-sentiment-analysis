# %%
# Imports all the libraries required
import os
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import geopy
from matplotlib.colors import rgb2hex
from descartes import PolygonPatch
from shapely.geometry import Polygon, MultiPolygon
from collections import Counter

# %%
df = pd.read_csv('cleaned_twitter_data_50000_sample.csv', index_col=0)
df.head()
# Out:
#         initial_index           tweet_created_at  \
# 439298         560631  2016-09-08 13:56:16+00:00
# 326531         417258  2016-09-01 09:31:56+00:00
# 313954         400256  2016-08-31 23:16:48+00:00
# 450210         573828  2016-09-08 23:21:16+00:00
# 182803         230748  2016-08-23 17:40:01+00:00
#
#                        user_created_at  \
# 439298  Sat May 16 17:31:28 +0000 2009
# 326531  Tue Oct 26 17:08:21 +0000 2010
# 313954  Wed Dec 14 05:41:00 +0000 2011
# 450210  Mon Aug 08 21:35:38 +0000 2016
# 182803  Wed Feb 17 16:55:49 +0000 2010
#
#                                                      text             user_id  \
# 439298       ['hillaryclinton', 'hit', 'one', 'reporter']            40504632
# 326531  ['hillaryclinton', 'false', 'said', 'first', '...           208110094
# 313954  ['hillaryclinton', 'blew', 'invitation', 'pres...           436442356
# 450210  ['usaneedstrump', 'hillaryclinton', 'dailycall...  762764227052392449
# 182803  ['trump', 'tempcrab', 'orchard', 'ky', 'f', 'w...           115110145
#
#                    user_name  followers_count  friends_count user_lang  \
# 439298           joey gerdin              542            596        en
# 326531  M_Mexico_Great_Again              643            523        en
# 313954           Chris Harms              522            492        en
# 450210                FrankB                5             72        en
# 182803             Carl King               84             18        en
#
#        place_type    place_full_name  \
# 439298       city    Minneapolis, MN
# 326531       city     Ferry Pass, FL
# 313954      admin     Wisconsin, USA
# 450210      admin  Pennsylvania, USA
# 182803      admin      Kentucky, USA
#
#                                        place_bounding_box        country  \
# 439298  {'type': 'Polygon', 'coordinates': [[[-93.3295...  United States
# 326531  {'type': 'Polygon', 'coordinates': [[[-87.2476...  United States
# 313954  {'type': 'Polygon', 'coordinates': [[[-92.8894...  United States
# 450210  {'type': 'Polygon', 'coordinates': [[[-80.5198...  United States
# 182803  {'type': 'Polygon', 'coordinates': [[[-89.5715...  United States
#
#        tweet_lang  retweet_count  favorite_count        states candidate
# 439298         en              0               0     Minnesota   clinton
# 326531         en              0               0       Florida   clinton
# 313954         en              0               0     Wisconsin   clinton
# 450210         en              0               0  Pennsylvania   clinton
# 182803         en              0               0      Kentucky     trump

# %%
id_instances = df['user_name'].tolist()
print(id_instances[:10])

# All unique ID strings, aka all unique users in the dataset
IDs = Counter(id_instances).keys()

# Counts the number of occurences of every ID.
tweet_frequency = Counter(id_instances).values()
# Out:
# ['Red Octopus', 'Beverly Spence', 'Asa DeMatteo, Ph.D.', 'Rafael Alejandro', 'tom b', 'Kim Wasson', 'Mechadave', 'David Mills', 'robert troxel', 'Brewgan']
# dict_keys(['Red Octopus', 'Beverly Spence', 'Asa DeMatteo, Ph.D.', 'Rafael Alejandro', 'tom b', 'Kim Wasson', 'Mechadave', 'David Mills', 'robert troxel', 'Brewgan', 'Michael Varvel', 'C.C.', 'Extremely Careless', 'Ellen', "It's Me, Greg!", 'William Kath', 'Herman Sims', 'Ron Joseph(NYOC)', 'Mike Nellis', 'Mike Carlson', 'Richard CoeurdeLion', 'Jerry lamb', 'Stephen C. Rose', 'Matt Butler', 'Jon Angel', 'Michael Cohen', 'Amanda Ferguson', 'Joseph Polsinello', 'SOCIAL BUTTRFLY RN', 'Debra Coreno', 'In My Element', 'Nancy Earley', 'Deborah Barnett Jump', 'Mariano Q. Casilum', 'Gary M. Corigliano', 'louise lloyd', 'Jules', 'Dagmar Christa Veen', 'GIL DUPUY', 'michelle sakasewa', 'Susan #BernieOrBust', 'Misti Jackson', 'LL Garrett', 'Michael Arendt', 'Jan Lella', 'maureen s', 'ベンソン.ベニ', 'skandali', 'Linda JustaNygirl', 'tom Morrison', 'Bernie Parness', 'Claudia Kabat', 'Algernon', 'Lee Carter', 'Stephanie', 'Tony Tiburon', 'Wm Favre Slater, III', 'Barbara Musser', 'Luis M Soto', 'Jason Bergkamp', 'Paul 3.2 :-/', 'Linda Pledger', 'Daniel R Adams', 'paul frederick', 'Robert Holmes', 'Glenn Korn', 'Lester Duke', 'Dennis Rivera', 'Jeff Gaskill', 'Shauj Gjiyn Miynj', 'BarbaraBuon', 'World Be Free', 'Joe the Infidel', 'michael d gillespie', 'ETA E-RocK', 'Linda', 'Debbie Carroll #MAGA', 'Jerry d.', 'JmzMadison', 'Tom D', 'Pigeon Eye', 'Anita DeCianni-Brown', '#StopTrumpNow', 'Robert Paul', 'Anita', 'Zane Richardson', 'Karen Thomas', 'D. Johnson', 'Bill Bishop', 'Kurt M. Richardson', 'Kelli Smith', 'BeautifulSoulSpeaks', 'David Roth, AIA', 'PFC Edwards', 'Tom Carr', 'susan', 'Peter Frady', 'Miss Mary', 'Katie', 'Berlain Hatfield', 'Anthony Petropoulos', 'squid25', 'Mickey D', 'Vivian Brown', 'Jack', 'goldenboy', 'Kaluš', 'Angela Parks', 'Richard Jorgensen', 'Philly Jewish Voice', 'walter Bowden', 'Alice Schulte', 'Seth Rich KIA by DNC', 'Jodie Toombs', 'nunyabusiness', 'Chase Cunningham', 'Mrs.Sarah Gibson', 'Kate V', 'Linda Berghof', 'Bishop Greg M. Davis', 'Barb Christianson', 'Ulysses Adkins', 'Alain V Berrebi', 'jacquelinephillips', 'Wendy Griggs', 'Charles Oriuwa', 'JohnMartinVetsHealth', 'Damon Chetson', 'LeoKapakos', 'Democrats4Trump', 'James R Wade', 'Andrejs Eglitis', 'Ric Davenport', 'mikerusty52@gmail.co', 'José Trump', 'Rich Bielecki', 'Frogger', 'Josh Martin', 'I Stand With Trump!', 'Scott Brinton', 'Carol Marie Walker', 'Boca Legend', 'Matt Adkins', 'Jeff Hubbard', 'Rodger Austin', 'Jonny Utah', 'Kathryn Como', 'Jim Getten', 'Phx Ken', 'Patrick Lewis', 'Toni Buerkert', 'bkatz', 'Jeff Barrett', 'Sherry Gay-Dagnogo', 'Elfinqueen', '=WHITE MAN=', 'Christianah', 'Alex Peterson TV', 'Chris Hungate', 'Mike', 'Ryan Gautschi', 'Timothy Gilligan', 'Sandeep Sharma', '(((Steph)))', 'Sherry Hildebrand', 'Craig Coelho', 'jeanette aloisio', 'Lionel', 'Kim R. Westbury', 'Alex A. Gomez ©', 'salpie', 'Simone Cuccurullo', 'Ron Pollock', 'Sapient', 'GR Vimont', 'Nix The Narrative ✘', 'Bob Moonbear', 'Mario Lujan', 'DNO', 'Mr. Casonoppus', 'Cool Breeze', 'wittsendconsulting', 'Martha Moore', 'Bruce Marion', 'Trumpedelic', 'Chief', 'Francisco L.', 'david kohlbach', 'me', 'Jim LaCoursiere', 'michael b martin', 'Allan V. Convey', 'nolapatriot', 'Bern Piccolomini', 'Kamakitty', '(((John Bachman)))', '(((Rob Goldston)))', 'Lacy Thomas', 'Eleanor Cooper', 'Antiamnesty', 'Brian Dolan', 'Liz', 'Dano', 'Imad Kassem', 'Wayne G Blum', 'Mark Shubin', 'Joyce Edwards', 'BRAS', 'sunsetbeachgirl', 'Borny', 'Elva Eubanks', 'Andy Cooper', 'Vance Hinebaugh', 'Chris Waugh', 'Matt Small', 'Arvel Mauldin', 'Donna McEvoy', '((( Kelly P )))', 'Lucas', 'Calvin Harris', 'Freefalling', 'Gail.48', 'Sushant Pradhan', 'Yvonne Haney', 'Johana⚾️', 'Kylo Ren Jr.', 'rotkoff', 'Saddam Hossain', 'Golfrnsavh™ ⛳', 'Maggie M. Salem', 'The Morch Files', 'deborah Litalien', 'Golden Wayne Moss jr', 'Paul Rabin', 'Stephanie Ann', 'Doug Pitorak', 'Joe American', 'Consuela', 'Unclaimed Mysteries', 'Christopher Fezza sr', 'jaazee', 'DADDY ICE', 'Lorem', 'Darci Isherwood', 'Cheryl', 'Dotti ...

# %%
user_freq = dict(zip(IDs, tweet_frequency))
print(user_freq)
# Out:
# {'Red Octopus': 76, 'Beverly Spence': 448, 'Asa DeMatteo, Ph.D.': 58, 'Rafael Alejandro': 31, 'tom b': 69, 'Kim Wasson': 45, 'Mechadave': 164, 'David Mills': 2, 'robert troxel': 1, 'Brewgan': 9, 'Michael Varvel': 56, 'C.C.': 93, 'Extremely Careless': 7, 'Ellen': 50, "It's Me, Greg!": 86, 'William Kath': 14, 'Herman Sims': 179, 'Ron Joseph(NYOC)': 38, 'Mike Nellis': 3, 'Mike Carlson': 50, 'Richard CoeurdeLion': 274, 'Jerry lamb': 10, 'Stephen C. Rose': 4, 'Matt Butler': 1, 'Jon Angel': 12, 'Michael Cohen': 73, 'Amanda Ferguson': 1, 'Joseph Polsinello': 629, 'SOCIAL BUTTRFLY RN': 52, 'Debra Coreno': 24, 'In My Element': 77, 'Nancy Earley': 19, 'Deborah Barnett Jump': 1, 'Mariano Q. Casilum': 244, 'Gary M. Corigliano': 1, 'louise lloyd': 10, 'Jules': 18, 'Dagmar Christa Veen': 2, 'GIL DUPUY': 111, 'michelle sakasewa': 14, 'Susan #BernieOrBust': 21, 'Misti Jackson': 271, 'LL Garrett': 101, 'Michael Arendt': 26, 'Jan Lella': 8, 'maureen s': 27, 'ベンソン.ベニ': 9, 'skandali': 2, 'Linda JustaNygirl': 2, 'tom Morrison': 5, 'Bernie Parness': 161, 'Claudia Kabat': 123, 'Algernon': 38, 'Lee Carter': 19, 'Stephanie': 32, 'Tony Tiburon': 3, 'Wm Favre Slater, III': 42, 'Barbara Musser': 8, 'Luis M Soto': 31, 'Jason Bergkamp': 240, 'Paul 3.2 :-/': 62, 'Linda Pledger': 46, 'Daniel R Adams': 1, 'paul frederick': 26, 'Robert Holmes': 6, 'Glenn Korn': 222, 'Lester Duke': 18, 'Dennis Rivera': 96, 'Jeff Gaskill': 66, 'Shauj Gjiyn Miynj': 24, 'BarbaraBuon': 83, 'World Be Free': 17, 'Joe the Infidel': 44, 'michael d gillespie': 4, 'ETA E-RocK': 63, 'Linda': 1096, 'Debbie Carroll #MAGA': 164, 'Jerry d.': 123, 'JmzMadison': 113, 'Tom D': 1, 'Pigeon Eye': 210, 'Anita DeCianni-Brown': 5, '#StopTrumpNow': 287, 'Robert Paul': 112, 'Anita': 81, 'Zane Richardson': 6, 'Karen Thomas': 1, 'D. Johnson': 24, 'Bill Bishop': 2, 'Kurt M. Richardson': 16, 'Kelli Smith': 11, 'BeautifulSoulSpeaks': 11, 'David Roth, AIA': 53, 'PFC Edwards': 12, 'Tom Carr': 1, 'susan': 239, 'Peter Frady': 47, 'Miss Mary': 28, 'Katie': 85, 'Berlain Hatfield': 9, 'Anthony Petropoulos': 24, 'squid25': 52, 'Mickey D': 27, 'Vivian Brown': 100, 'Jack': 36, 'goldenboy': 1, 'Kaluš': 10, 'Angela Parks': 44, 'Richard Jorgensen': 18, 'Philly Jewish Voice': 20, 'walter Bowden': 68, 'Alice Schulte': 5, 'Seth Rich KIA by DNC': 10, 'Jodie Toombs': 1, 'nunyabusiness': 15, 'Chase Cunningham': 15, 'Mrs.Sarah Gibson': 172, 'Kate V': 17, 'Linda Berghof': 5, 'Bishop Greg M. Davis': 80, 'Barb Christianson': 150, 'Ulysses Adkins': 2, 'Alain V Berrebi': 67, 'jacquelinephillips': 140, 'Wendy Griggs': 2, 'Charles Oriuwa': 79, 'JohnMartinVetsHealth': 12, 'Damon Chetson': 3, 'LeoKapakos': 25, 'Democrats4Trump': 94, 'James R Wade': 16, 'Andrejs Eglitis': 4, 'Ric Davenport': 2, 'mikerusty52@gmail.co': 255, 'José Trump': 5, 'Rich Bielecki': 2, 'Frogger': 203, 'Josh Martin': 11, 'I Stand With Trump!': 351, 'Scott Brinton': 30, 'Carol Marie Walker': 32, 'Boca Legend': 48, 'Matt Adkins': 2, 'Jeff Hubbard': 4, 'Rodger Austin': 68, 'Jonny Utah': 1, 'Kathryn Como': 5, 'Jim Getten': 10, 'Phx Ken': 26, 'Patrick Lewis': 47, 'Toni Buerkert': 17, 'bkatz': 6, 'Jeff Barrett': 203, 'Sherry Gay-Dagnogo': 6, 'Elfinqueen': 9, '=WHITE MAN=': 367, 'Christianah': 56, 'Alex Peterson TV': 1, 'Chris Hungate': 1, 'Mike': 466, 'Ryan Gautschi': 6, 'Timothy Gilligan': 14, 'Sandeep Sharma': 1, '(((Steph)))': 8, 'Sherry Hildebrand': 12, 'Craig Coelho': 7, 'jeanette aloisio': 10, 'Lionel': 32, 'Kim R. Westbury': 1, 'Alex A. Gomez ©': 1, 'salpie': 244, 'Simone Cuccurullo': 3, 'Ron Pollock': 3, 'Sapient': 78, 'GR Vimont': 42, 'Nix The Narrative ✘': 89, 'Bob Moonbear': 39, 'Mario Lujan': 108, 'DNO': 16, 'Mr. Casonoppus': 1, 'Cool Breeze': 1, 'wittsendconsulting': 7, 'Martha Moore': 22, 'Bruce Marion': 27, 'Trumpedelic': 264, 'Chief': 96, 'Francisco L.': 45, 'david kohlbach': 226, 'me': 105, 'Jim LaCoursiere': 57, 'michael b martin': 43, 'Allan V. Convey': 39, 'nolapatriot': 52, 'Bern Piccolomini': 2, 'Kamakitty': 33, '(((John Bachman)))': 12, '(((Rob Gol ...

# %%
unique_users2 = pd.DataFrame(data=IDs, index=None, columns =['ID'])
unique_users2['tweet_frequency'] = tweet_frequency


#followers_count = df['followers_count'].tolist()
#followers_count[:10]

# %%
IDs[:20]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-a925083e19e5> in <module>
# ----> 1 IDs[:20]
#
# TypeError: 'dict_keys' object is not subscriptable

# %%
#unique_users = pd.DataFrame(data=id_instances, index=None, columns =['ID'])
#unique_users['followers_count'] = followers_count
#unique_users.sort_values(['ID'], axis=1, inplace=True)

#unique_users.drop_duplicates(subset = "ID", keep = False, inplace = True)
#unique_users['unique_tweets'] = tweet_frequency
user_dict = {}

for row in range(df.shape[0]):
    if (df.iloc[row, 2]) not in user_dict.keys():
        user_dict[df.iloc[row, 2]] = []
        user_dict[df.iloc[row, 2]].append(df.iloc[row, 3])
    else:
        user_dict[df.iloc[row, 2]].append(df.iloc[row, 3])
        


# data.drop_duplicates(subset ="First Name", keep = False, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-b06232ae732e> in <module>
#      15
#      16 for x in list(user_dict)[0:10]:
# ---> 17     print (x, mydict[x])
#      18
#      19 # data.drop_duplicates(subset ="First Name", keep = False, inplace = True)
#
# NameError: name 'mydict' is not defined

# %%
user_dict_avg_followers = {}
for k,v in user_dict.items():
    user_dict_avg_followers[k] = sum(v) / len(v)

# %%
print(user_dict_avg_followers)
# Out:
# {'Red Octopus': 564.9736842105264, 'Beverly Spence': 2700.363839285714, 'Asa DeMatteo, Ph.D.': 197.01724137931035, 'Rafael Alejandro': 797.2903225806451, 'tom b': 69.65217391304348, 'Kim Wasson': 328.5777777777778, 'Mechadave': 329.1890243902439, 'David Mills': 38.0, 'robert troxel': 47.0, 'Brewgan': 257.55555555555554, 'Michael Varvel': 691.3571428571429, 'C.C.': 345.7741935483871, 'Extremely Careless': 382.14285714285717, 'Ellen': 1418.84, "It's Me, Greg!": 421.0, 'William Kath': 133.07142857142858, 'Herman Sims': 76.17877094972067, 'Ron Joseph(NYOC)': 3944.4473684210525, 'Mike Nellis': 28953.333333333332, 'Mike Carlson': 914.0, 'Richard CoeurdeLion': 2368.514598540146, 'Jerry lamb': 17.8, 'Stephen C. Rose': 236230.0, 'Matt Butler': 64.0, 'Jon Angel': 2482.75, 'Michael Cohen': 74051.65753424658, 'Amanda Ferguson': 631.0, 'Joseph Polsinello': 1441.925278219396, 'SOCIAL BUTTRFLY RN': 2709.0384615384614, 'Debra Coreno': 988.5, 'In My Element': 293.24675324675326, 'Nancy Earley': 10.263157894736842, 'Deborah Barnett Jump': 257.0, 'Mariano Q. Casilum': 1266.8237704918033, 'Gary M. Corigliano': 9.0, 'louise lloyd': 3461.2, 'Jules': 187.33333333333334, 'Dagmar Christa Veen': 3185.0, 'GIL DUPUY': 183.7927927927928, 'michelle sakasewa': 71.21428571428571, 'Susan #BernieOrBust': 1665.8095238095239, 'Misti Jackson': 7929.933579335793, 'LL Garrett': 962.3465346534654, 'Michael Arendt': 36.53846153846154, 'Jan Lella': 1970.125, 'maureen s': 830.1481481481482, 'ベンソン.ベニ': 12559.222222222223, 'skandali': 16.0, 'Linda JustaNygirl': 6.5, 'tom Morrison': 1222.4, 'Bernie Parness': 45.08695652173913, 'Claudia Kabat': 7473.642276422765, 'Algernon': 584.5263157894736, 'Lee Carter': 2683.6315789473683, 'Stephanie': 421.40625, 'Tony Tiburon': 646.6666666666666, 'Wm Favre Slater, III': 3392.690476190476, 'Barbara Musser': 2870.625, 'Luis M Soto': 38.67741935483871, 'Jason Bergkamp': 61168.25833333333, 'Paul 3.2 :-/': 4974.532258064516, 'Linda Pledger': 87.45652173913044, 'Daniel R Adams': 1.0, 'paul frederick': 11.5, 'Robert Holmes': 1251.1666666666667, 'Glenn Korn': 270.92792792792795, 'Lester Duke': 12.222222222222221, 'Dennis Rivera': 14.34375, 'Jeff Gaskill': 32.878787878787875, 'Shauj Gjiyn Miynj': 385.7916666666667, 'BarbaraBuon': 40.963855421686745, 'World Be Free': 1148.3529411764705, 'Joe the Infidel': 1059.2045454545455, 'michael d gillespie': 835.5, 'ETA E-RocK': 544.5396825396825, 'Linda': 190.6021897810219, 'Debbie Carroll #MAGA': 1487.8597560975609, 'Jerry d.': 19.178861788617887, 'JmzMadison': 6846.017699115044, 'Tom D': 10.0, 'Pigeon Eye': 40.75238095238095, 'Anita DeCianni-Brown': 1297.2, '#StopTrumpNow': 512.5644599303135, 'Robert Paul': 1584.0357142857142, 'Anita': 249.5679012345679, 'Zane Richardson': 45.0, 'Karen Thomas': 12.0, 'D. Johnson': 109.0, 'Bill Bishop': 53041.0, 'Kurt M. Richardson': 746.4375, 'Kelli Smith': 3760.090909090909, 'BeautifulSoulSpeaks': 356.0, 'David Roth, AIA': 3359.3584905660377, 'PFC Edwards': 1095.5833333333333, 'Tom Carr': 25.0, 'susan': 225.8828451882845, 'Peter Frady': 262.2340425531915, 'Miss Mary': 4500.714285714285, 'Katie': 297.7294117647059, 'Berlain Hatfield': 17.0, 'Anthony Petropoulos': 601.9166666666666, 'squid25': 61.21153846153846, 'Mickey D': 2116.8518518518517, 'Vivian Brown': 869.03, 'Jack': 83.38888888888889, 'goldenboy': 57.0, 'Kaluš': 944.5, 'Angela Parks': 23.75, 'Richard Jorgensen': 84.55555555555556, 'Philly Jewish Voice': 476.95, 'walter Bowden': 113.5, 'Alice Schulte': 34.4, 'Seth Rich KIA by DNC': 1117.4, 'Jodie Toombs': 143.0, 'nunyabusiness': 333.4, 'Chase Cunningham': 46.46666666666667, 'Mrs.Sarah Gibson': 4091.6162790697676, 'Kate V': 351.47058823529414, 'Linda Berghof': 551.8, 'Bishop Greg M. Davis': 43850.8, 'Barb Christianson': 965.5733333333334, 'Ulysses Adkins': 1581.5, 'Alain V Berrebi': 1783.5671641791046, 'jacquelinephillips': 218.45714285714286, 'Wendy Griggs': 116.5, 'Charles Oriuwa': 20.240506329113924, 'JohnMartinVetsHealth': 285.6666666666667, 'Damon Chetson':  ...

# %%
# followers, in the 'user' 'followers_count' field: checks each tweet until it matches the first unique entry listed
# in the IDs list, then puts that ID together with its followers in a dict. It then searches for the second unique
# user and fetches their followers.

x = 0 
for row in df:
    if df['unique_tweets_count'] == unique_users
df['unique_tweets_count'] = np.where(df['user_name'] == unique_users['ID'], unique_users['unique_tweets'], np.nan)

df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-fb0c55a265d4> in <module>
#       5 x = 0
#       6
# ----> 7 df['unique_tweets_count'] = np.where(df['user_name'] == unique_users['ID'], unique_users['unique_tweets'], np.nan)
#       8
#       9 df.head()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     522
#     523         if isinstance(other, ABCSeries) and not self._indexed_same(other):
# --> 524             raise ValueError("Can only compare identically-labeled Series objects")
#     525
#     526         lvalues = extract_array(self, extract_numpy=True)
#
# ValueError: Can only compare identically-labeled Series objects

# %%
x=0
for index, row in df.iterrows():
    if row['user_name'] == unique_users.iat[x,1]:
        row['unique_tweets_count'] = unique_users.iat[x,2]
        x += 1
    else:
        pass
df.head()
    
# Making a new column mapping the follower count onto the right user:
    
#id_data['followers'] = id_data['ID'].map(follower_count_dict)
