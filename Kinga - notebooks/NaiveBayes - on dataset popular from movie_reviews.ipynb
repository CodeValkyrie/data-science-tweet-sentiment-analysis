# %% [markdown]
# ### TRAINING BAYES MODEL WITH CODE FROM THE CLASS

# %%
# This snippet downloads the most popular datasets for experimenting with NLTK functionalities.
import nltk
nltk.download('popular')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# True

# %%
import nltk.classify.util
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import movie_reviews


# A function that extracts which words exist in a text based on a list of words to which we compare.
def word_feats(words):
        return dict([(word, True) for word in words])

# Get the negative reviews for movies    
negids = movie_reviews.fileids('neg')

# Get the positive reviews for movies
posids = movie_reviews.fileids('pos')
 
# Find the features that most correspond to negative reviews    
negfeats = [(word_feats(movie_reviews.words(fileids=[f])), 'neg') for f in negids]

# Find the features that most correspond to positive reviews
posfeats = [(word_feats(movie_reviews.words(fileids=[f])), 'pos') for f in posids]

# We would only use 1500 instances to train on. The quarter of the reviews left is for testing purposes.
negcutoff = int(len(negfeats)*3/4)
poscutoff = int(len(posfeats)*3/4)

# %%
negfeats[1]
# Out:
# ({'the': True,
#   'happy': True,
#   'bastard': True,
#   "'": True,
#   's': True,
#   'quick': True,
#   'movie': True,
#   'review': True,
#   'damn': True,
#   'that': True,
#   'y2k': True,
#   'bug': True,
#   '.': True,
#   'it': True,
#   'got': True,
#   'a': True,
#   'head': True,
#   'start': True,
#   'in': True,
#   'this': True,
#   'starring': True,
#   'jamie': True,
#   'lee': True,
#   'curtis': True,
#   'and': True,
#   'another': True,
#   'baldwin': True,
#   'brother': True,
#   '(': True,
#   'william': True,
#   'time': True,
#   ')': True,
#   'story': True,
#   'regarding': True,
#   'crew': True,
#   'of': True,
#   'tugboat': True,
#   'comes': True,
#   'across': True,
#   'deserted': True,
#   'russian': True,
#   'tech': True,
#   'ship': True,
#   'has': True,
#   'strangeness': True,
#   'to': True,
#   'when': True,
#   'they': True,
#   'kick': True,
#   'power': True,
#   'back': True,
#   'on': True,
#   'little': True,
#   'do': True,
#   'know': True,
#   'within': True,
#   'going': True,
#   'for': True,
#   'gore': True,
#   'bringing': True,
#   'few': True,
#   'action': True,
#   'sequences': True,
#   'here': True,
#   'there': True,
#   ',': True,
#   'virus': True,
#   'still': True,
#   'feels': True,
#   'very': True,
#   'empty': True,
#   'like': True,
#   'all': True,
#   'flash': True,
#   'no': True,
#   'substance': True,
#   'we': True,
#   'don': True,
#   't': True,
#   'why': True,
#   'was': True,
#   'really': True,
#   'out': True,
#   'middle': True,
#   'nowhere': True,
#   'origin': True,
#   'what': True,
#   'took': True,
#   'over': True,
#   'just': True,
#   'big': True,
#   'pink': True,
#   'flashy': True,
#   'thing': True,
#   'hit': True,
#   'mir': True,
#   'course': True,
#   'donald': True,
#   'sutherland': True,
#   'is': True,
#   'stumbling': True,
#   'around': True,
#   'drunkenly': True,
#   'throughout': True,
#   '"': True,
#   'hey': True,
#   'let': True,
#   'chase': True,
#   'these': True,
#   'people': True,
#   'with': True,
#   'some': True,
#   'robots': True,
#   'acting': True,
#   'below': True,
#   'average': True,
#   'even': True,
#   'from': True,
#   'likes': True,
#   'you': True,
#   're': True,
#   'more': True,
#   'likely': True,
#   'get': True,
#   'her': True,
#   'work': True,
#   'halloween': True,
#   'h20': True,
#   'wasted': True,
#   'well': True,
#   'he': True,
#   'real': True,
#   'star': True,
#   'are': True,
#   'stan': True,
#   'winston': True,
#   'robot': True,
#   'design': True,
#   'schnazzy': True,
#   'cgi': True,
#   'occasional': True,
#   'good': True,
#   'shot': True,
#   'picking': True,
#   'into': True,
#   'someone': True,
#   'brain': True,
#   'so': True,
#   'if': True,
#   'body': True,
#   'parts': True,
#   'turn': True,
#   'your': True,
#   'otherwise': True,
#   'pretty': True,
#   'much': True,
#   'sunken': True},
#  'neg')

# %%
# Construct the training dataset containing 50% positive reviews and 50% negative reviews
trainfeats = negfeats[:negcutoff] + posfeats[:poscutoff]

# Construct the negative dataset containing 50% positive reviews and 50% negative reviews
testfeats = negfeats[negcutoff:] + posfeats[poscutoff:]

print ('train on %d instances, test on %d instances' % (len(trainfeats), len(testfeats)))

# Train a NaiveBayesClassifier
classifier = NaiveBayesClassifier.train(trainfeats)

# Test the trained classifier and display the most informative features.
print ('accuracy:', nltk.classify.util.accuracy(classifier, testfeats))
classifier.show_most_informative_features()
# Out:
# train on 1500 instances, test on 500 instances
# accuracy: 0.728
# Most Informative Features
#              magnificent = True              pos : neg    =     15.0 : 1.0
#              outstanding = True              pos : neg    =     13.6 : 1.0
#                insulting = True              neg : pos    =     13.0 : 1.0
#               vulnerable = True              pos : neg    =     12.3 : 1.0
#                ludicrous = True              neg : pos    =     11.8 : 1.0
#              uninvolving = True              neg : pos    =     11.7 : 1.0
#                   avoids = True              pos : neg    =     11.7 : 1.0
#               astounding = True              pos : neg    =     10.3 : 1.0
#              fascination = True              pos : neg    =     10.3 : 1.0
#                  idiotic = True              neg : pos    =      9.8 : 1.0

# %%
print (classifier.show_most_informative_features(32))
# Out:
# Most Informative Features
#              magnificent = True              pos : neg    =     15.0 : 1.0
#              outstanding = True              pos : neg    =     13.6 : 1.0
#                insulting = True              neg : pos    =     13.0 : 1.0
#               vulnerable = True              pos : neg    =     12.3 : 1.0
#                ludicrous = True              neg : pos    =     11.8 : 1.0
#              uninvolving = True              neg : pos    =     11.7 : 1.0
#                   avoids = True              pos : neg    =     11.7 : 1.0
#               astounding = True              pos : neg    =     10.3 : 1.0
#              fascination = True              pos : neg    =     10.3 : 1.0
#                  idiotic = True              neg : pos    =      9.8 : 1.0
#                affecting = True              pos : neg    =      9.7 : 1.0
#                   symbol = True              pos : neg    =      9.7 : 1.0
#                    mulan = True              pos : neg    =      9.0 : 1.0
#                    inept = True              neg : pos    =      9.0 : 1.0
#                   seagal = True              neg : pos    =      9.0 : 1.0
#                   annual = True              pos : neg    =      9.0 : 1.0
#                illogical = True              neg : pos    =      9.0 : 1.0
#                animators = True              pos : neg    =      9.0 : 1.0
#                 bothered = True              neg : pos    =      9.0 : 1.0
#                 palpable = True              pos : neg    =      8.3 : 1.0
#                represent = True              pos : neg    =      8.3 : 1.0
#                strengths = True              pos : neg    =      8.3 : 1.0
#               henstridge = True              neg : pos    =      8.3 : 1.0
#                   idiots = True              neg : pos    =      8.3 : 1.0
#                    moody = True              pos : neg    =      8.3 : 1.0
#                    naval = True              pos : neg    =      8.3 : 1.0
#                   azaria = True              neg : pos    =      8.3 : 1.0
#                maintains = True              pos : neg    =      8.2 : 1.0
#                   doubts = True              pos : neg    =      7.7 : 1.0
#                 fairness = True              neg : pos    =      7.7 : 1.0
#                  detract = True              pos : neg    =      7.7 : 1.0
#                   hatred = True              pos : neg    =      7.7 : 1.0
# None

# %%
trainfeats[1]
# Out:
# ({'the': True,
#   'happy': True,
#   'bastard': True,
#   "'": True,
#   's': True,
#   'quick': True,
#   'movie': True,
#   'review': True,
#   'damn': True,
#   'that': True,
#   'y2k': True,
#   'bug': True,
#   '.': True,
#   'it': True,
#   'got': True,
#   'a': True,
#   'head': True,
#   'start': True,
#   'in': True,
#   'this': True,
#   'starring': True,
#   'jamie': True,
#   'lee': True,
#   'curtis': True,
#   'and': True,
#   'another': True,
#   'baldwin': True,
#   'brother': True,
#   '(': True,
#   'william': True,
#   'time': True,
#   ')': True,
#   'story': True,
#   'regarding': True,
#   'crew': True,
#   'of': True,
#   'tugboat': True,
#   'comes': True,
#   'across': True,
#   'deserted': True,
#   'russian': True,
#   'tech': True,
#   'ship': True,
#   'has': True,
#   'strangeness': True,
#   'to': True,
#   'when': True,
#   'they': True,
#   'kick': True,
#   'power': True,
#   'back': True,
#   'on': True,
#   'little': True,
#   'do': True,
#   'know': True,
#   'within': True,
#   'going': True,
#   'for': True,
#   'gore': True,
#   'bringing': True,
#   'few': True,
#   'action': True,
#   'sequences': True,
#   'here': True,
#   'there': True,
#   ',': True,
#   'virus': True,
#   'still': True,
#   'feels': True,
#   'very': True,
#   'empty': True,
#   'like': True,
#   'all': True,
#   'flash': True,
#   'no': True,
#   'substance': True,
#   'we': True,
#   'don': True,
#   't': True,
#   'why': True,
#   'was': True,
#   'really': True,
#   'out': True,
#   'middle': True,
#   'nowhere': True,
#   'origin': True,
#   'what': True,
#   'took': True,
#   'over': True,
#   'just': True,
#   'big': True,
#   'pink': True,
#   'flashy': True,
#   'thing': True,
#   'hit': True,
#   'mir': True,
#   'course': True,
#   'donald': True,
#   'sutherland': True,
#   'is': True,
#   'stumbling': True,
#   'around': True,
#   'drunkenly': True,
#   'throughout': True,
#   '"': True,
#   'hey': True,
#   'let': True,
#   'chase': True,
#   'these': True,
#   'people': True,
#   'with': True,
#   'some': True,
#   'robots': True,
#   'acting': True,
#   'below': True,
#   'average': True,
#   'even': True,
#   'from': True,
#   'likes': True,
#   'you': True,
#   're': True,
#   'more': True,
#   'likely': True,
#   'get': True,
#   'her': True,
#   'work': True,
#   'halloween': True,
#   'h20': True,
#   'wasted': True,
#   'well': True,
#   'he': True,
#   'real': True,
#   'star': True,
#   'are': True,
#   'stan': True,
#   'winston': True,
#   'robot': True,
#   'design': True,
#   'schnazzy': True,
#   'cgi': True,
#   'occasional': True,
#   'good': True,
#   'shot': True,
#   'picking': True,
#   'into': True,
#   'someone': True,
#   'brain': True,
#   'so': True,
#   'if': True,
#   'body': True,
#   'parts': True,
#   'turn': True,
#   'your': True,
#   'otherwise': True,
#   'pretty': True,
#   'much': True,
#   'sunken': True},
#  'neg')

# %%
# Construct our features based on which tweets contain which word
def extract_features(document):
    document_words = set(document)
    features = {}
    for word in movie_reviews.words():
        features['%s' % word] = (word in document_words)
    return features
 
    
def word_feats(words):
        return dict([(word, True) for word in words])

# %%
tweet = 'Larry is my friend'
word_feats(tweet.split())
# Out:
# {'Larry': True, 'is': True, 'my': True, 'friend': True}

# %%
# The tweet we are about to classify
tweet = 'Anna is one of my friends'
print (classifier.classify(word_feats(tweet.split())))
# Out:
# pos

# %% [markdown]
# ### TEST THE MODEL WITH MANUALLY LABELLED DATA

# %% [markdown]
# Testing accuracy for hand labelled data from twitter elections, hand labelling was perform randomly on a selected data as taking them with a time order would be biased due to the events from the elections

# %%
import pandas as pd
from datetime import datetime
from tqdm import tqdm

test_politics_tweets = pd.read_excel("random_tweets_as_a_test_labeled.xlsx")
test_politics_tweets
# Out:
#      Unnamed: 0                                               text sentiment
# 0        184569  @johnand2015 @wme98 @TrumpDynastyUSA @realDona...       pos
# 1        602960           @realDonaldTrump AMERICANS WANT A CHANGE       pos
# 2        412384  @realDonaldTrump is all in, I'm all in. Histor...       pos
# 3        423577  @JoeFreedomLove @FreeBeacon \nThat's Because T...       neg
# 4        647595  Not pneumonia symptoms: Med guideline requires...       neg
# ..          ...                                                ...       ...
# 295      495873  @USA_FREEDOM_NOW @klmstlouis @realDonaldTrump ...       neg
# 296      615525  #Hillary is corrupting, lying to our young peo...       neg
# 297      325430  @andylefko @KeithOlbermann @realDonaldTrump @S...       neg
# 298      460252  @amjoyshow #AMJoy #Trump is ripping off part o...       neg
# 299      566450  Marxist Speak From The 'Village Idiot'. https:...       neg
#
# [300 rows x 3 columns]

# %% [markdown]
# Data cleaning

# %%
import numpy as np
import pandas as pd
import re
from spellchecker import SpellChecker
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
import demoji
from bs4 import BeautifulSoup
demoji.download_codes()

# Initializes the spell checker, tokenizer and lammatizer.
check = SpellChecker()
tokenizer = RegexpTokenizer(r'\w+')
lemma = WordNetLemmatizer()

# Create a set of stopwords
stop_words = set(stopwords.words('english'))



# Cleaning functions

########################### FUNCTIONS ###################################
def correct_text(text):
# text needs to be a list of clean word tokens without other characters.
    misspelled = check.unknown(text)
    for word in misspelled:
        text[text.index(word)] = check.correction(word)
    return text

def lemmatize_text(text):
    return [lemma.lemmatize(word) for word in text]

# removing punctuation
def rm_punctuation(record: str) -> str:
    s = re.sub(r'[^\w\s]', '', record)
    return s


# removing stopwords - i.e. the, a, an, he\
def rm_stopwords(record: str) -> str:
    words = list(record.split(' '))
    filtered_sentence = ' '.join([w for w in words if not w in stop_words])
    return filtered_sentence

# removeing emoji
def rm_emoji(record: str) -> str:
    plain = demoji.replace(record, " ")
    return plain

# Removing html coding
def rm_html(record: str) -> str:
    soup = BeautifulSoup(record, 'html.parser')
    plain = soup.get_text()
    return plain


# A function that extracts which words exist in a text based on a list of words to which we compare.
def word_feats(words):
    return dict([(word, True) for word in words])
# Out:
# Downloading emoji data ...
# ... OK (Got response in 0.55 seconds)
# Writing emoji data to C:\Users\PC\.demoji\codes.json ...
# ... OK

# %%
test_politics_tweets.loc[:, 'normalized'] = test_politics_tweets['text'].apply(lambda x: re.sub(r'https?://[^\s<>"]+|www\.[^\s<>"]+', "", x))
print("Regex done at:", datetime.now())
test_politics_tweets.loc[:, 'normalized'] = test_politics_tweets['normalized'].apply(lambda x: re.sub(r'[0-9]+', ' ', x))
print("Numbers replaced at:", datetime.now())
test_politics_tweets.loc[:, 'normalized'] = test_politics_tweets['normalized'].apply(lambda x: re.sub(r'\_', ' ', x))
print("Floors replaced at:", datetime.now())
test_politics_tweets.loc[:, 'normalized'] = test_politics_tweets['normalized'].apply(lambda x: re.sub(r'@|#', ' ', x))
print("Hashtags done at:", datetime.now())
test_politics_tweets.loc[:, 'normalized'] = test_politics_tweets['normalized'].apply(lambda x: x.lower())
print("Lowered at:", datetime.now())
test_politics_tweets.loc[:, 'normalized'] = test_politics_tweets['normalized'].apply(lambda x: rm_punctuation(x))
print("Punctuation done at:", datetime.now())
test_politics_tweets.loc[:, 'normalized'] = test_politics_tweets['normalized'].apply(lambda x: rm_stopwords(x))
print("Stop words bye at:", datetime.now())
test_politics_tweets.loc[:, 'normalized'] = test_politics_tweets['normalized'].apply(lambda x: x.rstrip())
print("Whitespaces done at:", datetime.now())
#test_politics_tweets.loc[:, 'normalized'] = test_politics_tweets['normalized'].apply(lambda x: tokenizer.tokenize(x))
#print("Tokenized at:", datetime.now())
#test_politics_tweets.loc[:, 'normalized'] = test_politics_tweets['normalized'].apply(lambda x: lemmatize_text(x))
#print("Lemmatized at:", datetime.now())
# Out:
# Regex done at: 2020-09-24 14:35:27.413998
# Numbers replaced at: 2020-09-24 14:35:27.428987
# Floors replaced at: 2020-09-24 14:35:27.441980
# Hashtags done at: 2020-09-24 14:35:27.452977
# Lowered at: 2020-09-24 14:35:27.466968
# Punctuation done at: 2020-09-24 14:35:27.508943
# Stop words bye at: 2020-09-24 14:35:27.535926
# Whitespaces done at: 2020-09-24 14:35:27.546921

# %%
from tqdm import tqdm
tqdm.pandas()

test_politics_tweets.loc[:, 'features'] = test_politics_tweets.progress_apply(lambda x: (word_feats(x.normalized.split()), x. sentiment), axis = 1)
test_politics_tweets['features']
# Out:
# 100%|██████████| 300/300 [00:00<00:00, 8828.50it/s]
# 0      ({'johnand': True, 'wme': True, 'trumpdynastyu...
# 1      ({'realdonaldtrump': True, 'americans': True, ...
# 2      ({'realdonaldtrump': True, 'im': True, 'histor...
# 3      ({'joefreedomlove': True, 'freebeacon': True, ...
# 4      ({'pneumonia': True, 'symptoms': True, 'med': ...
#                              ...
# 295    ({'usa': True, 'freedom': True, 'klmstlouis': ...
# 296    ({'hillary': True, 'corrupting': True, 'lying'...
# 297    ({'andylefko': True, 'keitholbermann': True, '...
# 298    ({'amjoyshow': True, 'amjoy': True, 'trump': T...
# 299    ({'marxist': True, 'speak': True, 'village': T...
# Name: features, Length: 300, dtype: object

# %%
test_politics_tweets['features'][1]
# Out:
# ({'realdonaldtrump': True, 'americans': True, 'want': True, 'change': True},
#  'pos')

# %%
# Select negative tweets marked by SentiStrenght  
negfeats = test_politics_tweets[test_politics_tweets['sentiment'] == 'neg']

# Select positive tweets marked by SentiStrenght
posfeats = test_politics_tweets[test_politics_tweets['sentiment'] == 'pos']

# We would only use 1500 instances to train on. The quarter of the reviews left is for testing purposes.
negcutoff = int(len(negfeats)*3/4)
poscutoff = int(len(posfeats)*3/4)

#negcutoff = 55
#poscutoff = 55

# %%
# Construct the negative dataset containing 50% positive reviews and 50% negative reviews
testfeats = pd.concat([negfeats[negcutoff:], posfeats[poscutoff:]])

# %%
# Test the trained classifier and display the most informative features.
print ('accuracy:', nltk.classify.util.accuracy(classifier, testfeats['features'].tolist()))
# Out:
# accuracy: 0.5352112676056338
# Most Informative Features
#              magnificent = True              pos : neg    =     15.0 : 1.0
#              outstanding = True              pos : neg    =     13.6 : 1.0
#                insulting = True              neg : pos    =     13.0 : 1.0
#               vulnerable = True              pos : neg    =     12.3 : 1.0
#                ludicrous = True              neg : pos    =     11.8 : 1.0
#              uninvolving = True              neg : pos    =     11.7 : 1.0
#                   avoids = True              pos : neg    =     11.7 : 1.0
#               astounding = True              pos : neg    =     10.3 : 1.0
#              fascination = True              pos : neg    =     10.3 : 1.0
#                  idiotic = True              neg : pos    =      9.8 : 1.0
#                affecting = True              pos : neg    =      9.7 : 1.0
#                   symbol = True              pos : neg    =      9.7 : 1.0
#                    mulan = True              pos : neg    =      9.0 : 1.0
#                    inept = True              neg : pos    =      9.0 : 1.0
#                   seagal = True              neg : pos    =      9.0 : 1.0
#                   annual = True              pos : neg    =      9.0 : 1.0
#                illogical = True              neg : pos    =      9.0 : 1.0
#                animators = True              pos : neg    =      9.0 : 1.0
#                 bothered = True              neg : pos    =      9.0 : 1.0
#                 palpable = True              pos : neg    =      8.3 : 1.0
#                represent = True              pos : neg    =      8.3 : 1.0
#                strengths = True              pos : neg    =      8.3 : 1.0
#               henstridge = True              neg : pos    =      8.3 : 1.0
#                   idiots = True              neg : pos    =      8.3 : 1.0
#                    moody = True              pos : neg    =      8.3 : 1.0
#                    naval = True              pos : neg    =      8.3 : 1.0
#                   azaria = True              neg : pos    =      8.3 : 1.0
#                maintains = True              pos : neg    =      8.2 : 1.0
#                   doubts = True              pos : neg    =      7.7 : 1.0
#                 fairness = True              neg : pos    =      7.7 : 1.0
#                  detract = True              pos : neg    =      7.7 : 1.0
#                   hatred = True              pos : neg    =      7.7 : 1.0
#                 embodies = True              pos : neg    =      7.7 : 1.0
#                ourselves = True              pos : neg    =      7.7 : 1.0
#                     slip = True              pos : neg    =      7.7 : 1.0
#                  studies = True              pos : neg    =      7.7 : 1.0
#                  gaining = True              pos : neg    =      7.7 : 1.0
#           excruciatingly = True              neg : pos    =      7.7 : 1.0
#                  offbeat = True              pos : neg    =      7.7 : 1.0
#                     anna = True              pos : neg    =      7.7 : 1.0

# %% [markdown]
# Assigning results to the tweets:

# %%
# The tweet we are about to classify
tweet = 'I like peanut butter idiots'
print (classifier.classify(word_feats(tweet.split())))
# Out:
# neg

# %% [markdown]
# Not quite good classificator I would say

# %% [markdown]
# ### ASSIGNING SENTIMENT TO TWEETS

# %% [markdown]
# Now we will assign sentiment to the tweets

# %%
import pandas as pd
data = pd.read_csv("cleaned_twitter_data_50000_sample.csv")
data
# Out:
#        Unnamed: 0  initial_index           tweet_created_at  \
# 0          439298         560631  2016-09-08 13:56:16+00:00
# 1          326531         417258  2016-09-01 09:31:56+00:00
# 2          313954         400256  2016-08-31 23:16:48+00:00
# 3          450210         573828  2016-09-08 23:21:16+00:00
# 4          182803         230748  2016-08-23 17:40:01+00:00
# ...           ...            ...                        ...
# 49995      109611         139329  2016-08-19 00:02:43+00:00
# 49996      224364         282945  2016-08-26 00:43:52+00:00
# 49997      402684         515797  2016-09-06 18:27:25+00:00
# 49998      234923         296196  2016-08-26 15:58:23+00:00
# 49999      508632         646423  2016-09-11 22:33:07+00:00
#
#                       user_created_at  \
# 0      Sat May 16 17:31:28 +0000 2009
# 1      Tue Oct 26 17:08:21 +0000 2010
# 2      Wed Dec 14 05:41:00 +0000 2011
# 3      Mon Aug 08 21:35:38 +0000 2016
# 4      Wed Feb 17 16:55:49 +0000 2010
# ...                               ...
# 49995  Sat Feb 11 23:08:46 +0000 2012
# 49996  Fri Mar 05 18:24:11 +0000 2010
# 49997  Sat Aug 06 22:45:14 +0000 2011
# 49998  Mon Jul 06 02:10:25 +0000 2015
# 49999  Fri Apr 03 22:40:51 +0000 2009
#
#                                                     text             user_id  \
# 0           ['hillaryclinton', 'hit', 'one', 'reporter']            40504632
# 1      ['hillaryclinton', 'false', 'said', 'first', '...           208110094
# 2      ['hillaryclinton', 'blew', 'invitation', 'pres...           436442356
# 3      ['usaneedstrump', 'hillaryclinton', 'dailycall...  762764227052392449
# 4      ['trump', 'tempcrab', 'orchard', 'ky', 'f', 'w...           115110145
# ...                                                  ...                 ...
# 49995  ['hillaryiscoming', 'ivanroberson', 'kickstart...           489825874
# 49996  ['id', 'like', 'ban', 'trump', 'word', 'harden...           120182490
# 49997  ['obama', 'clinton', 'created', 'world', 'powe...           349921132
# 49998  ['hillaryclinton', 'keep', 'america', 'sane', ...          3269554988
# 49999  ['decline', 'know', 'trying', 'get', 'replace'...            28673900
#
#                   user_name  followers_count  friends_count user_lang  \
# 0               joey gerdin              542            596        en
# 1      M_Mexico_Great_Again              643            523        en
# 2               Chris Harms              522            492        en
# 3                    FrankB                5             72        en
# 4                 Carl King               84             18        en
# ...                     ...              ...            ...       ...
# 49995               Kal AKA              495            990        en
# 49996          jenny speier              254            193        en
# 49997        Michael Wilner            10443            661        en
# 49998                cjlamb             1817           1886        en
# 49999         Kristin Slape             3864           4858        en
#
#       place_type    place_full_name  \
# 0           city    Minneapolis, MN
# 1           city     Ferry Pass, FL
# 2          admin     Wisconsin, USA
# 3          admin  Pennsylvania, USA
# 4          admin      Kentucky, USA
# ...          ...                ...
# 49995       city    Los Angeles, CA
# 49996      admin       Indiana, USA
# 49997       city     Washington, DC
# 49998      admin       Indiana, USA
# 49999       city     Naperville, IL
#
#                                       place_bounding_box        country  \
# 0      {'type': 'Polygon', 'coordinates': [[[-93.3295...  United States
# 1      {'type': 'Polygon', 'coordinates': [[[-87.2476...  United States
# 2      {'type': 'Polygon', 'coordinates': [[[-92.8894...  United States
# 3      {'type': 'Polygon', 'coordinates': [[[-80.5198...  United States
# 4      {'type': 'Polygon', 'coordinates': [[[-89.5715...  United States
# ...                                                  ...            ...
# 49995  {'type': 'Polygon', 'coordinates': [[[-118.668...  United States
# 49996  {'type': 'Polygon', 'coordinates': [[[-88.0978...  United States
# 49997  {'type': 'Polygon', 'coordinates': [[[-77.1194...  United States
# 49998  {'type': 'Polygon', 'coordinates': [[[-88.0978...  United States
# 49999  {'type': 'Polygon', 'coordinates': [[[-88.2595...  United States
#
#       tweet_lang  retweet_count  favorite_count        states candidate
# 0             en              0               0     Minnesota   clinton
# 1             en              0               0       Florida   clinton
# 2             en              0               0     Wisconsin   clinton
# 3             en              0               0  Pennsylvania   clinton
# 4             en              0               0      Kentucky     trump
# ...          ...            ...             ...           ...       ...
# 49995         en              0               0    California   clinton
# 49996         en              0               0       Indiana     trump
# 49997         en              0               0    Washington     trump
# 49998         en              0               0       Indiana   clinton
# 49999         en              0               0      Illinois   clinton
#
# [50000 rows x 19 columns]

# %%
data_before_processing = pd.read_csv('tweets_only_eng_and_US_without_cleaning_2020-09-24.csv')
data_before_processing = data_before_processing.rename(columns = {"text":"initial_tweet_text", "Unnamed: 0":"initial_index"})
data_before_processing
# Out:
#         initial_index           tweet_created_at  \
# 0                   1  2016-08-12 10:04:02+00:00
# 1                   4  2016-08-12 10:04:30+00:00
# 2                   5  2016-08-12 10:04:46+00:00
# 3                   7  2016-08-12 10:04:48+00:00
# 4                   8  2016-08-12 10:04:48+00:00
# ...               ...                        ...
# 517133         657300  2016-09-12 13:20:28+00:00
# 517134         657302  2016-09-12 13:20:32+00:00
# 517135         657303  2016-09-12 13:20:33+00:00
# 517136         657305  2016-09-12 13:20:38+00:00
# 517137         657306  2016-09-12 13:20:48+00:00
#
#                        user_created_at  \
# 0       Thu Oct 15 00:28:04 +0000 2009
# 1       Mon Aug 20 09:43:48 +0000 2012
# 2       Tue May 19 03:18:19 +0000 2009
# 3       Sun Aug 07 00:57:29 +0000 2016
# 4       Wed Oct 28 18:34:22 +0000 2009
# ...                                ...
# 517133  Sun Jul 10 16:13:13 +0000 2011
# 517134  Wed May 02 22:48:50 +0000 2012
# 517135  Fri Apr 01 21:42:36 +0000 2016
# 517136  Wed Jun 10 08:43:55 +0000 2015
# 517137  Mon May 10 00:49:18 +0000 2010
#
#                                        initial_tweet_text             user_id  \
# 0       @BarackObama \n@FBI\n@LORETTALYNCH \nALL IN CO...            82496193
# 1       #CNN #newday clear #Trump deliberately throwin...           769208504
# 2       @realDonaldTrump, you wouldn't recognize a lie...            41043316
# 3       "Kid, you know, suing someone? Thats the most ...  762090248159371264
# 4       @HillaryClinton you ARE the co-founder of ISIS...            85879639
# ...                                                   ...                 ...
# 517133  @CNBC @SquawkAlley @realDonaldTrump Kudlow is ...           332888709
# 517134  TRUMP U, TAXES ,WEIRD MEDICAL REPORT WITH A WH...           569487350
# 517135  @CarolCNN if MSM were honest watch any utube v...  716017946166857728
# 517136  It's interesting that Hillary Clinton's crowds...          3241116564
# 517137  @TeamTrump @KellyannePolls @realDonaldTrump @f...           142113417
#
#                   user_name  followers_count  friends_count user_lang  \
# 0               Red Octopus              531            677        en
# 1            Beverly Spence             2652           2976        en
# 2       Asa DeMatteo, Ph.D.              183             98        en
# 3          Rafael Alejandro              159            993        en
# 4                     tom b               68            268        en
# ...                     ...              ...            ...       ...
# 517133  Linda Mannes Wildes             2097           2716        en
# 517134      Sheryl Berghoff             1997           2599        en
# 517135              Karen B              756           1229        en
# 517136       Robert Chaffin             2827           3970        en
# 517137                Linda              240            170        en
#
#        place_type   place_full_name  \
# 0            city   Baton Rouge, LA
# 1            city     Baltimore, MD
# 2            city  Palm Springs, CA
# 3            city      Secaucus, NJ
# 4            city        Irving, TX
# ...           ...               ...
# 517133      admin      Florida, USA
# 517134       city     San Diego, CA
# 517135       city  Coral Gables, FL
# 517136       city     Fairbanks, AK
# 517137      admin      Florida, USA
#
#                                        place_bounding_box        country  \
# 0       {'type': 'Polygon', 'coordinates': [[[-91.2189...  United States
# 1       {'type': 'Polygon', 'coordinates': [[[-76.7115...  United States
# 2       {'type': 'Polygon', 'coordinates': [[[-116.567...  United States
# 3       {'type': 'Polygon', 'coordinates': [[[-74.0938...  United States
# 4       {'type': 'Polygon', 'coordinates': [[[-97.0341...  United States
# ...                                                   ...            ...
# 517133  {'type': 'Polygon', 'coordinates': [[[-87.6346...  United States
# 517134  {'type': 'Polygon', 'coordinates': [[[-117.282...  United States
# 517135  {'type': 'Polygon', 'coordinates': [[[-80.2971...  United States
# 517136  {'type': 'Polygon', 'coordinates': [[[-147.813...  United States
# 517137  {'type': 'Polygon', 'coordinates': [[[-87.6346...  United States
#
#        tweet_lang  retweet_count  favorite_count
# 0              en              0               0
# 1              en              0               0
# 2              en              0               0
# 3              en              0               0
# 4              en              0               0
# ...           ...            ...             ...
# 517133         en              0               0
# 517134         en              0               0
# 517135         en              0               0
# 517136         en              0               0
# 517137         en              0               0
#
# [517138 rows x 16 columns]

# %%
data_before_processing = data_before_processing[['initial_index','initial_tweet_text']]
data_before_processing = data_before_processing.rename(columns = {"text":"initial_tweet_text"})
data = pd.merge(left=data, right=data_before_processing, how='left', left_on='initial_index', right_on='initial_index')
data.head()
# Out:
#    Unnamed: 0  initial_index           tweet_created_at  \
# 0      439298         560631  2016-09-08 13:56:16+00:00
# 1      326531         417258  2016-09-01 09:31:56+00:00
# 2      313954         400256  2016-08-31 23:16:48+00:00
# 3      450210         573828  2016-09-08 23:21:16+00:00
# 4      182803         230748  2016-08-23 17:40:01+00:00
#
#                   user_created_at  \
# 0  Sat May 16 17:31:28 +0000 2009
# 1  Tue Oct 26 17:08:21 +0000 2010
# 2  Wed Dec 14 05:41:00 +0000 2011
# 3  Mon Aug 08 21:35:38 +0000 2016
# 4  Wed Feb 17 16:55:49 +0000 2010
#
#                                                 text             user_id  \
# 0       ['hillaryclinton', 'hit', 'one', 'reporter']            40504632
# 1  ['hillaryclinton', 'false', 'said', 'first', '...           208110094
# 2  ['hillaryclinton', 'blew', 'invitation', 'pres...           436442356
# 3  ['usaneedstrump', 'hillaryclinton', 'dailycall...  762764227052392449
# 4  ['trump', 'tempcrab', 'orchard', 'ky', 'f', 'w...           115110145
#
#               user_name  followers_count  friends_count user_lang place_type  \
# 0           joey gerdin              542            596        en       city
# 1  M_Mexico_Great_Again              643            523        en       city
# 2           Chris Harms              522            492        en      admin
# 3                FrankB                5             72        en      admin
# 4             Carl King               84             18        en      admin
#
#      place_full_name                                 place_bounding_box  \
# 0    Minneapolis, MN  {'type': 'Polygon', 'coordinates': [[[-93.3295...
# 1     Ferry Pass, FL  {'type': 'Polygon', 'coordinates': [[[-87.2476...
# 2     Wisconsin, USA  {'type': 'Polygon', 'coordinates': [[[-92.8894...
# 3  Pennsylvania, USA  {'type': 'Polygon', 'coordinates': [[[-80.5198...
# 4      Kentucky, USA  {'type': 'Polygon', 'coordinates': [[[-89.5715...
#
#          country tweet_lang  retweet_count  favorite_count        states  \
# 0  United States         en              0               0     Minnesota
# 1  United States         en              0               0       Florida
# 2  United States         en              0               0     Wisconsin
# 3  United States         en              0               0  Pennsylvania
# 4  United States         en              0               0      Kentucky
#
#   candidate                                 initial_tweet_text
# 0   clinton  Did @HillaryClinton just hit on one of the rep...
# 1   clinton  @HillaryClinton false. He said first 2 years o...
# 2   clinton  .@HillaryClinton blew off an invitation by the...
# 3   clinton  @USAneedsTRUMP @HillaryClinton @DailyCaller Ha...
# 4     trump  #Trump in 2016 Temp:Crab Orchard, Ky.":83.1°F ...

# %%
data.to_csv("cleaned_twitter_data_50000_sample_with_original_text_20200924.csv")

# %%
from tqdm import tqdm, tqdm_notebook
tqdm_notebook().pandas()

data.loc[:, 'cleaned_for_bayes'] = data['initial_tweet_text'].apply(lambda x: re.sub(r'https?://[^\s<>"]+|www\.[^\s<>"]+', "", x))
print("Regex done at:", datetime.now())
data.loc[:, 'cleaned_for_bayes'] = data['cleaned_for_bayes'].progress_apply(lambda x: rm_html(x))
print("XTML decoding deleted at:", datetime.now())
#data.loc[:, 'normalized'] = data['normalized'].apply(lambda x: rm_newline(x))
#print("Newlines cleaned at:", datetime.now())
data.loc[:, 'cleaned_for_bayes'] = data['cleaned_for_bayes'].apply(lambda x: re.sub(r'@|#', ' ', x))
print("Hashtags done at:", datetime.now())
data.loc[:, 'cleaned_for_bayes'] = data['cleaned_for_bayes'].apply(lambda x: re.sub(r'[0-9]+', ' ', x))
print("Numbers replaced at:", datetime.now())
data.loc[:, 'cleaned_for_bayes'] = data['cleaned_for_bayes'].apply(lambda x: re.sub(r'\_', ' ', x))
print("Numbers replaced at:", datetime.now())
data.loc[:, 'cleaned_for_bayes'] = data['cleaned_for_bayes'].apply(lambda x: rm_punctuation(x))
print("Punctuation done at:", datetime.now())
data.loc[:, 'cleaned_for_bayes'] = data['cleaned_for_bayes'].apply(lambda x: rm_stopwords(x))
print("Stop words bye at:", datetime.now())
data.loc[:, 'cleaned_for_bayes'] = data['cleaned_for_bayes'].apply(lambda x: x.rstrip())
print("Whitespaces done at:", datetime.now())
data.loc[:, 'cleaned_for_bayes'] = data['cleaned_for_bayes'].apply(lambda x: x.lower())
print("Lowered at:", datetime.now())
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Regex done at: 2020-09-24 14:49:43.477986
# HBox(children=(IntProgress(value=0, max=50000), HTML(value='')))
# XTML decoding deleted at: 2020-09-24 14:49:57.394849
# Hashtags done at: 2020-09-24 14:49:57.722339
# Numbers replaced at: 2020-09-24 14:49:58.077139
# Numbers replaced at: 2020-09-24 14:49:58.227051
# Punctuation done at: 2020-09-24 14:49:58.605835
# Stop words bye at: 2020-09-24 14:49:59.079551
# Whitespaces done at: 2020-09-24 14:49:59.139518
# Lowered at: 2020-09-24 14:49:59.204482

# %% [markdown]
# Now we perform all the same pipeline as for test data

# %%
tweet = data['cleaned_for_bayes'][1]
print (classifier.classify(word_feats(tweet.split())))
print(tweet)
# Out:
# pos
#  hillaryclinton false he said first   years criminals then new flow stoppep drugs carteld evaluate

# %%
word_feats(tweet.split())
# Out:
# {'hillaryclinton': True,
#  'false': True,
#  'he': True,
#  'said': True,
#  'first': True,
#  'years': True,
#  'criminals': True,
#  'then': True,
#  'new': True,
#  'flow': True,
#  'stoppep': True,
#  'drugs': True,
#  'carteld': True,
#  'evaluate': True}

# %%
tweet = data['text'][12]
tweet = '@oybay @BillKristol @Sarahlellison @Evan_McMullin @TheTakeaway   Dont give IDIOT any ideas!  MorallyUnfit MentallyUnstable. NeverTrump'
print (classifier.classify(word_feats(tweet.split())))
print(tweet)
# Out:
# neg
# @oybay @BillKristol @Sarahlellison @Evan_McMullin @TheTakeaway   Dont give IDIOT any ideas!  MorallyUnfit MentallyUnstable. NeverTrump

# %%
data.loc[:, 'bayes_sentiment'] = data['cleaned_for_bayes'].progress_apply(lambda x: classifier.classify(word_feats(x.split())))
print("Adding sentiment done at:", datetime.now())
data
# Out:
# HBox(children=(IntProgress(value=0, max=50000), HTML(value='')))
# Adding sentiment done at: 2020-09-24 15:03:43.093041
#        Unnamed: 0  initial_index           tweet_created_at  \
# 0          439298         560631  2016-09-08 13:56:16+00:00
# 1          326531         417258  2016-09-01 09:31:56+00:00
# 2          313954         400256  2016-08-31 23:16:48+00:00
# 3          450210         573828  2016-09-08 23:21:16+00:00
# 4          182803         230748  2016-08-23 17:40:01+00:00
# ...           ...            ...                        ...
# 49995      109611         139329  2016-08-19 00:02:43+00:00
# 49996      224364         282945  2016-08-26 00:43:52+00:00
# 49997      402684         515797  2016-09-06 18:27:25+00:00
# 49998      234923         296196  2016-08-26 15:58:23+00:00
# 49999      508632         646423  2016-09-11 22:33:07+00:00
#
#                       user_created_at  \
# 0      Sat May 16 17:31:28 +0000 2009
# 1      Tue Oct 26 17:08:21 +0000 2010
# 2      Wed Dec 14 05:41:00 +0000 2011
# 3      Mon Aug 08 21:35:38 +0000 2016
# 4      Wed Feb 17 16:55:49 +0000 2010
# ...                               ...
# 49995  Sat Feb 11 23:08:46 +0000 2012
# 49996  Fri Mar 05 18:24:11 +0000 2010
# 49997  Sat Aug 06 22:45:14 +0000 2011
# 49998  Mon Jul 06 02:10:25 +0000 2015
# 49999  Fri Apr 03 22:40:51 +0000 2009
#
#                                                     text             user_id  \
# 0           ['hillaryclinton', 'hit', 'one', 'reporter']            40504632
# 1      ['hillaryclinton', 'false', 'said', 'first', '...           208110094
# 2      ['hillaryclinton', 'blew', 'invitation', 'pres...           436442356
# 3      ['usaneedstrump', 'hillaryclinton', 'dailycall...  762764227052392449
# 4      ['trump', 'tempcrab', 'orchard', 'ky', 'f', 'w...           115110145
# ...                                                  ...                 ...
# 49995  ['hillaryiscoming', 'ivanroberson', 'kickstart...           489825874
# 49996  ['id', 'like', 'ban', 'trump', 'word', 'harden...           120182490
# 49997  ['obama', 'clinton', 'created', 'world', 'powe...           349921132
# 49998  ['hillaryclinton', 'keep', 'america', 'sane', ...          3269554988
# 49999  ['decline', 'know', 'trying', 'get', 'replace'...            28673900
#
#                   user_name  followers_count  friends_count user_lang  ...  \
# 0               joey gerdin              542            596        en  ...
# 1      M_Mexico_Great_Again              643            523        en  ...
# 2               Chris Harms              522            492        en  ...
# 3                    FrankB                5             72        en  ...
# 4                 Carl King               84             18        en  ...
# ...                     ...              ...            ...       ...  ...
# 49995               Kal AKA              495            990        en  ...
# 49996          jenny speier              254            193        en  ...
# 49997        Michael Wilner            10443            661        en  ...
# 49998                cjlamb             1817           1886        en  ...
# 49999         Kristin Slape             3864           4858        en  ...
#
#                                       place_bounding_box        country  \
# 0      {'type': 'Polygon', 'coordinates': [[[-93.3295...  United States
# 1      {'type': 'Polygon', 'coordinates': [[[-87.2476...  United States
# 2      {'type': 'Polygon', 'coordinates': [[[-92.8894...  United States
# 3      {'type': 'Polygon', 'coordinates': [[[-80.5198...  United States
# 4      {'type': 'Polygon', 'coordinates': [[[-89.5715...  United States
# ...                                                  ...            ...
# 49995  {'type': 'Polygon', 'coordinates': [[[-118.668...  United States
# 49996  {'type': 'Polygon', 'coordinates': [[[-88.0978...  United States
# 49997  {'type': 'Polygon', 'coordinates': [[[-77.1194...  United States
# 49998  {'type': 'Polygon', 'coordinates': [[[-88.0978...  United States
# 49999  {'type': 'Polygon', 'coordinates': [[[-88.2595...  United States
#
#       tweet_lang retweet_count favorite_count        states  candidate  \
# 0             en             0              0     Minnesota    clinton
# 1             en             0              0       Florida    clinton
# 2             en             0              0     Wisconsin    clinton
# 3             en             0              0  Pennsylvania    clinton
# 4             en             0              0      Kentucky      trump
# ...          ...           ...            ...           ...        ...
# 49995         en             0              0    California    clinton
# 49996         en             0              0       Indiana      trump
# 49997         en             0              0    Washington      trump
# 49998         en             0              0       Indiana    clinton
# 49999         en             0              0      Illinois    clinton
#
#                                       initial_tweet_text  \
# 0      Did @HillaryClinton just hit on one of the rep...
# 1      @HillaryClinton false. He said first 2 years o...
# 2      .@HillaryClinton blew off an invitation by the...
# 3      @USAneedsTRUMP @HillaryClinton @DailyCaller Ha...
# 4      #Trump in 2016 Temp:Crab Orchard, Ky.":83.1°F ...
# ...                                                  ...
# 49995  @HillaryIsComing @Ivanroberson #Kickstarter ?#...
# 49996  I'd like to ban having #trump &amp; the word #...
# 49997  #Obama and #Clinton "have created what will be...
# 49998  @HillaryClinton \nKeep America Sane:\nVote Cli...
# 49999  She is on a decline, they know it, they trying...
#
#                                        cleaned_for_bayes bayes_sentiment
# 0                  did  hillaryclinton hit one reporters             pos
# 1       hillaryclinton false he said first   years cr...             pos
# 2       hillaryclinton blew invitation president mexi...             pos
# 3       usaneedstrump  hillaryclinton  dailycaller ha...             pos
# 4       trump   tempcrab orchard ky  f wind  mph pres...             pos
# ...                                                  ...             ...
# 49995   hillaryiscoming  ivanroberson  kickstarter  t...             neg
# 49996  id like ban  trump  word  hardening sentence f...             neg
# 49997   obama  clinton created world power  trump say...             pos
# 49998   hillaryclinton \nkeep america sane\nvote clin...             neg
# 49999  she decline know trying get  replace  hillarys...             neg
#
# [50000 rows x 22 columns]

# %%
data[data['bayes_sentiment']=='pos']
# Out:
#        Unnamed: 0  initial_index           tweet_created_at  \
# 0          439298         560631  2016-09-08 13:56:16+00:00
# 1          326531         417258  2016-09-01 09:31:56+00:00
# 2          313954         400256  2016-08-31 23:16:48+00:00
# 3          450210         573828  2016-09-08 23:21:16+00:00
# 4          182803         230748  2016-08-23 17:40:01+00:00
# ...           ...            ...                        ...
# 49988       33069          42003  2016-08-14 10:19:53+00:00
# 49990      204829         258459  2016-08-25 02:01:50+00:00
# 49991      412130         527541  2016-09-07 04:09:46+00:00
# 49994      403008         516195  2016-09-06 18:42:23+00:00
# 49997      402684         515797  2016-09-06 18:27:25+00:00
#
#                       user_created_at  \
# 0      Sat May 16 17:31:28 +0000 2009
# 1      Tue Oct 26 17:08:21 +0000 2010
# 2      Wed Dec 14 05:41:00 +0000 2011
# 3      Mon Aug 08 21:35:38 +0000 2016
# 4      Wed Feb 17 16:55:49 +0000 2010
# ...                               ...
# 49988  Sun Apr 19 21:21:38 +0000 2009
# 49990  Thu Jul 07 00:11:14 +0000 2011
# 49991  Sun Mar 10 01:15:32 +0000 2013
# 49994  Sun Jan 17 00:26:30 +0000 2010
# 49997  Sat Aug 06 22:45:14 +0000 2011
#
#                                                     text             user_id  \
# 0           ['hillaryclinton', 'hit', 'one', 'reporter']            40504632
# 1      ['hillaryclinton', 'false', 'said', 'first', '...           208110094
# 2      ['hillaryclinton', 'blew', 'invitation', 'pres...           436442356
# 3      ['usaneedstrump', 'hillaryclinton', 'dailycall...  762764227052392449
# 4      ['trump', 'tempcrab', 'orchard', 'ky', 'f', 'w...           115110145
# ...                                                  ...                 ...
# 49988  ['az', 'valentine', 'bringbackjobs', 'savechri...            33315551
# 49990  ['politico', 'realdonaldtrump', 'nigel', 'fara...           330676972
# 49991  ['megynkelly', 'realdonaldtrump', 'ap', 'hilla...          1255784834
# 49994  ['based', 'cnn', 'special', 'last', 'night', '...           105635023
# 49997  ['obama', 'clinton', 'created', 'world', 'powe...           349921132
#
#                   user_name  followers_count  friends_count user_lang  ...  \
# 0               joey gerdin              542            596        en  ...
# 1      M_Mexico_Great_Again              643            523        en  ...
# 2               Chris Harms              522            492        en  ...
# 3                    FrankB                5             72        en  ...
# 4                 Carl King               84             18        en  ...
# ...                     ...              ...            ...       ...  ...
# 49988        Robert Witcher              887           1100        en  ...
# 49990          Greg Pittman               48            210        en  ...
# 49991           jojo capece              316             72        en  ...
# 49994       Tabatha Presley              210            656        en  ...
# 49997        Michael Wilner            10443            661        en  ...
#
#                                       place_bounding_box        country  \
# 0      {'type': 'Polygon', 'coordinates': [[[-93.3295...  United States
# 1      {'type': 'Polygon', 'coordinates': [[[-87.2476...  United States
# 2      {'type': 'Polygon', 'coordinates': [[[-92.8894...  United States
# 3      {'type': 'Polygon', 'coordinates': [[[-80.5198...  United States
# 4      {'type': 'Polygon', 'coordinates': [[[-89.5715...  United States
# ...                                                  ...            ...
# 49988  {'type': 'Polygon', 'coordinates': [[[-85.6051...  United States
# 49990  {'type': 'Polygon', 'coordinates': [[[-80.2081...  United States
# 49991  {'type': 'Polygon', 'coordinates': [[[-122.514...  United States
# 49994  {'type': 'Polygon', 'coordinates': [[[-84.2027...  United States
# 49997  {'type': 'Polygon', 'coordinates': [[[-77.1194...  United States
#
#       tweet_lang retweet_count favorite_count        states  candidate  \
# 0             en             0              0     Minnesota    clinton
# 1             en             0              0       Florida    clinton
# 2             en             0              0     Wisconsin    clinton
# 3             en             0              0  Pennsylvania    clinton
# 4             en             0              0      Kentucky      trump
# ...          ...           ...            ...           ...        ...
# 49988         en             0              0       Georgia      trump
# 49990         en             0              0       Florida      trump
# 49991         en             0              0    California      trump
# 49994         en             0              0       Georgia      trump
# 49997         en             0              0    Washington      trump
#
#                                       initial_tweet_text  \
# 0      Did @HillaryClinton just hit on one of the rep...
# 1      @HillaryClinton false. He said first 2 years o...
# 2      .@HillaryClinton blew off an invitation by the...
# 3      @USAneedsTRUMP @HillaryClinton @DailyCaller Ha...
# 4      #Trump in 2016 Temp:Crab Orchard, Ky.":83.1°F ...
# ...                                                  ...
# 49988  @az_valentine @BringBackJobs @savechristians t...
# 49990  @politico @realDonaldTrump @Nigel_Farage trump...
# 49991  @megynkelly @realDonaldTrump @AP HILLARY HAS C...
# 49994  Based on the @CNN special last night on @realD...
# 49997  #Obama and #Clinton "have created what will be...
#
#                                        cleaned_for_bayes bayes_sentiment
# 0                  did  hillaryclinton hit one reporters             pos
# 1       hillaryclinton false he said first   years cr...             pos
# 2       hillaryclinton blew invitation president mexi...             pos
# 3       usaneedstrump  hillaryclinton  dailycaller ha...             pos
# 4       trump   tempcrab orchard ky  f wind  mph pres...             pos
# ...                                                  ...             ...
# 49988   az valentine  bringbackjobs  savechristians t...             pos
# 49990   politico  realdonaldtrump  nigel farage trump...             pos
# 49991   megynkelly  realdonaldtrump  ap hillary has c...             pos
# 49994  based  cnn special last night  realdonaldtrump...             pos
# 49997   obama  clinton created world power  trump say...             pos
#
# [29572 rows x 22 columns]

# %% [markdown]
# Saving sentiment data from Naive

# %%
data.to_csv("tweets_50k_with_bayes_sentiment_20200924.csv")
